# %%
import re

# %%
file = open("poor_amazon_toy_reviews.txt")
regex_pattern = r'(?P<hour>1?\d):(?P<minute>[0-5]\d)\s?(?P<indicator>:am|pm)'
file.seek(0)
reviews = file.readlines()
for review in reviews:
    match = re.search(regex_pattern, review)
    if match:
        print(match.groupdict())

# %%
regex_pattern = r'(?P<currency>\$)(?P<dollars>\d+)\.(?P<cents>\d+)?'
file.seek(0)
reviews = file.readlines()
for review in reviews:
    match = re.search(regex_pattern, review)
    if match:
        print(match.groupdict())
# Out:
# {'currency': '$', 'dollars': '10', 'cents': '00'}
# {'currency': '$', 'dollars': '753', 'cents': '00'}
# {'currency': '$', 'dollars': '10', 'cents': None}
# {'currency': '$', 'dollars': '9', 'cents': '99'}
# {'currency': '$', 'dollars': '3', 'cents': '18'}
# {'currency': '$', 'dollars': '5', 'cents': None}
# {'currency': '$', 'dollars': '250', 'cents': '00'}
# {'currency': '$', 'dollars': '19', 'cents': '99'}
# {'currency': '$', 'dollars': '69', 'cents': None}
# {'currency': '$', 'dollars': '7', 'cents': '00'}
# {'currency': '$', 'dollars': '100', 'cents': None}
# {'currency': '$', 'dollars': '65', 'cents': None}
# {'currency': '$', 'dollars': '9', 'cents': '80'}
# {'currency': '$', 'dollars': '7', 'cents': '00'}
# {'currency': '$', 'dollars': '12', 'cents': '99'}
# {'currency': '$', 'dollars': '50', 'cents': None}
# {'currency': '$', 'dollars': '50', 'cents': None}
# {'currency': '$', 'dollars': '2', 'cents': '99'}
# {'currency': '$', 'dollars': '43', 'cents': '98'}
# {'currency': '$', 'dollars': '1', 'cents': '00'}
# {'currency': '$', 'dollars': '19', 'cents': '99'}
# {'currency': '$', 'dollars': '10', 'cents': '00'}
# {'currency': '$', 'dollars': '35', 'cents': '98'}
# {'currency': '$', 'dollars': '7', 'cents': '71'}
# {'currency': '$', 'dollars': '89', 'cents': '99'}
# {'currency': '$', 'dollars': '27', 'cents': '97'}
# {'currency': '$', 'dollars': '1', 'cents': '00'}
# {'currency': '$', 'dollars': '5', 'cents': '00'}
# {'currency': '$', 'dollars': '8', 'cents': '00'}
# {'currency': '$', 'dollars': '8', 'cents': None}
# {'currency': '$', 'dollars': '26', 'cents': None}
# {'currency': '$', 'dollars': '5', 'cents': '00'}
# {'currency': '$', 'dollars': '8', 'cents': '00'}
# {'currency': '$', 'dollars': '3', 'cents': None}
# {'currency': '$', 'dollars': '16', 'cents': '99'}
# {'currency': '$', 'dollars': '30', 'cents': '00'}
# {'currency': '$', 'dollars': '13', 'cents': None}
# {'currency': '$', 'dollars': '11', 'cents': '50'}
# {'currency': '$', 'dollars': '12', 'cents': None}
# {'currency': '$', 'dollars': '50', 'cents': None}
# {'currency': '$', 'dollars': '1', 'cents': None}
# {'currency': '$', 'dollars': '20', 'cents': None}
# {'currency': '$', 'dollars': '15', 'cents': '00'}
# {'currency': '$', 'dollars': '12', 'cents': '00'}
# {'currency': '$', 'dollars': '27', 'cents': '99'}
# {'currency': '$', 'dollars': '29', 'cents': '99'}
# {'currency': '$', 'dollars': '50', 'cents': None}
# {'currency': '$', 'dollars': '20', 'cents': None}
# {'currency': '$', 'dollars': '40', 'cents': '00'}
# {'currency': '$', 'dollars': '19', 'cents': None}
# {'currency': '$', 'dollars': '100', 'cents': None}
# {'currency': '$', 'dollars': '30', 'cents': None}
# {'currency': '$', 'dollars': '22', 'cents': '00'}
# {'currency': '$', 'dollars': '1', 'cents': '68'}
# {'currency': '$', 'dollars': '60', 'cents': '00'}
# {'currency': '$', 'dollars': '9', 'cents': '30'}
# {'currency': '$', 'dollars': '10', 'cents': '99'}
# {'currency': '$', 'dollars': '20', 'cents': None}
# {'currency': '$', 'dollars': '5', 'cents': '25'}
# {'currency': '$', 'dollars': '40', 'cents': None}
# {'currency': '$', 'dollars': '8', 'cents': '99'}
# {'currency': '$', 'dollars': '2', 'cents': '89'}
# {'currency': '$', 'dollars': '2', 'cents': None}
# {'currency': '$', 'dollars': '8', 'cents': '00'}
# {'currency': '$', 'dollars': '5', 'cents': '00'}
# {'currency': '$', 'dollars': '19', 'cents': None}
# {'currency': '$', 'dollars': '5', 'cents': '00'}
# {'currency': '$', 'dollars': '0', 'cents': '99'}
# {'currency': '$', 'dollars': '42', 'cents': None}
# {'currency': '$', 'dollars': '6', 'cents': '00'}
# {'currency': '$', 'dollars': '80', 'cents': None}
# {'currency': '$', 'dollars': '5', 'cents': '00'}
# {'currency': '$', 'dollars': '1', 'cents': '00'}
# {'currency': '$', 'dollars': '100', 'cents': None}
# {'currency': '$', 'dollars': '9', 'cents': '75'}
# {'currency': '$', 'dollars': '5', 'cents': '00'}
# {'currency': '$', 'dollars': '75', 'cents': None}
# {'currency': '$', 'dollars': '6', 'cents': '95'}
# {'currency': '$', 'dollars': '5', 'cents': '00'}
# {'currency': '$', 'dollars': '20', 'cents': None}
# {'currency': '$', 'dollars': '11', 'cents': '99'}
# {'currency': '$', 'dollars': '196', 'cents': '69'}
# {'currency': '$', 'dollars': '32', 'cents': '99'}
# {'currency': '$', 'dollars': '4', 'cents': '99'}
# {'currency': '$', 'dollars': '32', 'cents': '99'}
# {'currency': '$', 'dollars': '900', 'cents': None}
# {'currency': '$', 'dollars': '1', 'cents': '00'}
# {'currency': '$', 'dollars': '30', 'cents': '00'}
# {'currency': '$', 'dollars': '6', 'cents': '95'}
# {'currency': '$', 'dollars': '14', 'cents': '73'}
# {'currency': '$', 'dollars': '25', 'cents': '00'}
# {'currency': '$', 'dollars': '699', 'cents': '99'}
# {'currency': '$', 'dollars': '5', 'cents': '50'}
# {'currency': '$', 'dollars': '13', 'cents': '46'}
# {'currency': '$', 'dollars': '5', 'cents': '00'}
# {'currency': '$', 'dollars': '190', 'cents': None}
# {'currency': '$', 'dollars': '15', 'cents': '00'}
# {'currency': '$', 'dollars': '1', 'cents': '99'}
# {'currency': '$', 'dollars': '4', 'cents': '99'}
# {'currency': '$', 'dollars': '10', 'cents': None}
# {'currency': '$', 'dollars': '42', 'cents': '00'}
# {'currency': '$', 'dollars': '9', 'cents': '99'}
# {'currency': '$', 'dollars': '5', 'cents': '99'}
# {'currency': '$', 'dollars': '3', 'cents': '43'}
# {'currency': '$', 'dollars': '50', 'cents': None}
# {'currency': '$', 'dollars': '2', 'cents': '99'}
# {'currency': '$', 'dollars': '6', 'cents': None}
# {'currency': '$', 'dollars': '22', 'cents': '00'}
# {'currency': '$', 'dollars': '20', 'cents': None}
# {'currency': '$', 'dollars': '3', 'cents': '70'}
# {'currency': '$', 'dollars': '15', 'cents': '95'}
# {'currency': '$', 'dollars': '175', 'cents': '00'}
# {'currency': '$', 'dollars': '14', 'cents': '95'}
# {'currency': '$', 'dollars': '369', 'cents': '00'}
# {'currency': '$', 'dollars': '10', 'cents': '00'}
# {'currency': '$', 'dollars': '6', 'cents': '99'}
# {'currency': '$', 'dollars': '2', 'cents': None}
# {'currency': '$', 'dollars': '10', 'cents': None}
# {'currency': '$', 'dollars': '6', 'cents': '99'}
# {'currency': '$', 'dollars': '37', 'cents': '00'}
# {'currency': '$', 'dollars': '12', 'cents': None}
# {'currency': '$', 'dollars': '40', 'cents': None}
# {'currency': '$', 'dollars': '1', 'cents': '75'}
# {'currency': '$', 'dollars': '20', 'cents': None}
# {'currency': '$', 'dollars': '4', 'cents': '99'}
# {'currency': '$', 'dollars': '16', 'cents': '00'}
# {'currency': '$', 'dollars': '5', 'cents': None}
# {'currency': '$', 'dollars': '15', 'cents': '36'}
# {'currency': '$', 'dollars': '30', 'cents': '00'}
# {'currency': '$', 'dollars': '13', 'cents': '47'}
# {'currency': '$', 'dollars': '129', 'cents': '00'}
# {'currency': '$', 'dollars': '19', 'cents': '95'}
# {'currency': '$', 'dollars': '12', 'cents': None}
# {'currency': '$', 'dollars': '119', 'cents': '00'}
# {'currency': '$', 'dollars': '37', 'cents': '00'}
# {'currency': '$', 'dollars': '100', 'cents': None}
# {'currency': '$', 'dollars': '24', 'cents': '99'}
# {'currency': '$', 'dollars': '3', 'cents': '00'}
# {'currency': '$', 'dollars': '12', 'cents': '00'}
# {'currency': '$', 'dollars': '4', 'cents': '49'}
# {'currency': '$', 'dollars': '46', 'cents': '95'}
# {'currency': '$', 'dollars': '10', 'cents': None}
# {'currency': '$', 'dollars': '5', 'cents': '00'}
# {'currency': '$', 'dollars': '23', 'cents': '00'}
# {'currency': '$', 'dollars': '40', 'cents': '00'}
# {'currency': '$', 'dollars': '20', 'cents': None}
# {'currency': '$', 'dollars': '10', 'cents': '00'}
# {'currency': '$', 'dollars': '19', 'cents': '99'}
# {'currency': '$', 'dollars': '15', 'cents': None}
# {'currency': '$', 'dollars': '10', 'cents': None}
# {'currency': '$', 'dollars': '12', 'cents': '99'}
# {'currency': '$', 'dollars': '20', 'cents': None}
# {'currency': '$', 'dollars': '25', 'cents': None}
# {'currency': '$', 'dollars': '4', 'cents': '99'}
# {'currency': '$', 'dollars': '15', 'cents': None}
# {'currency': '$', 'dollars': '2', 'cents': '95'}
# {'currency': '$', 'dollars': '49', 'cents': '99'}
# {'currency': '$', 'dollars': '10', 'cents': '00'}
# {'currency': '$', 'dollars': '2', 'cents': '99'}
# {'currency': '$', 'dollars': '8', 'cents': '99'}
# {'currency': '$', 'dollars': '16', 'cents': '00'}
# {'currency': '$', 'dollars': '50', 'cents': '00'}
# {'currency': '$', 'dollars': '8', 'cents': '00'}
# {'currency': '$', 'dollars': '6', 'cents': '99'}
# {'currency': '$', 'dollars': '19', 'cents': '99'}
# {'currency': '$', 'dollars': '150', 'cents': '00'}
# {'currency': '$', 'dollars': '5', 'cents': '00'}
# {'currency': '$', 'dollars': '500', 'cents': None}
# {'currency': '$', 'dollars': '8', 'cents': '00'}
# {'currency': '$', 'dollars': '5', 'cents': None}
# {'currency': '$', 'dollars': '19', 'cents': '00'}
# {'currency': '$', 'dollars': '5', 'cents': None}
# {'currency': '$', 'dollars': '8', 'cents': None}
# {'currency': '$', 'dollars': '23', 'cents': '00'}
# {'currency': '$', 'dollars': '10', 'cents': None}
# {'currency': '$', 'dollars': '9', 'cents': '98'}
